# %% [markdown]
# <div style="direction:rtl;line-height:300%;"><font face="XB Zar" size=5>
# <div style="direction:rtl;line-height:300%;"><font face="XB Zar" size=5>
# <div align=center>
# <font face="IranNastaliq" size=30>
# <p></p>
# به نام خدا
# </font>
# <br>
# <font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
# </font>
# <br>
# <font color=blue>
# داده‌ساختارها و الگوریتم‌ها
# </font>
# </div>
# علی شریفی زارچی
# <span style="float:left;">
# ترم دوم سال تحصیلی ۱۳۹۴-۹۵
# </span>
# <hr/>
# <font color=red size=6>
# <p></p>
#
# <div align=center>
# فصل چهاردهم: درهم‌سازی (جلسه نخست)
# </div>
# </font>
# <div align=left>
# پارسوآ خرسند و فرزاد عبدالحسینی
# </div>
# <hr>
#         <font color=#FF7500>
#         یک مساله ساده
#         </font><p></p>
#         فرض کنید مجموعه ‌از اعداد در بازه صفر تا صد داریم و می خواهیم داده ساختاری برای نگهداری آنها طراحی کنیم که امکان انجام
#         عملیات‌های
#         Find
#         ،
#         Insert
#         و
#         Delete
#         را در زمان
#         $O(1)$
#         داشته باشد
#         .
#         <br/>
#         <font color=#FF7500>
#         راه حل
#         </font><p></p>
#         از یک آرایه به طول صد استفاده می کنیم
#         .
#         اگر خانه
#         $i$
#         ام آرایه مقدار صفر داشته باشد، یعنی عدد
#         $i$
#         در مجموعه وجود ندارد و اگر مقدار آن یک باشد یعنی عدد
#         $i$
#         وجود دارد
#         .
#         به طور مشابه حذف اعداد با
#         صفر کردن خانه متناظر و اضافه کردن اعداد با یک کردن آن انجام می شود
#         .
#         <br/>
#         <font color="#FF7500">
#         یک مساله سخت‌تر
#         </font><p></p>
#         حال فرض کنید اعداد مساله بین صفر تا
#         $10^{12}$
#         هستند، اما می دانیم حداکثر
#         $10^3$
#         عدد در مجموعه وجود خواهد داشت
#         .
#         <font color="#FF7500">
#         همان راه‌حل قبلی؟
#         </font><p></p>
#     </font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font size=6 color=#48aff1>
# 		<p></p>
# 		تابع درهم ‌سازی
# 		<p></p>
# 		</font>
# 		<hr>
# 		تابع در‌هم سازی
# 		$h:D\rightarrow L$
# 		تابعی است که
# 		مجموعه‌ای با اندازه دلخواه
# 		(
# 		و احتمالا خیلی بزرگ
# 		)
# 		$D$
# 		از داده‌ها را به مجموعه‌
# 		با اندازه ثابت
# 		$L$
# 		نگاشت می‌دهد
# 		.
# 		<br>
# 		از توابع درهم ‌ساز دامنه کاربردهای گسترده‌ای در  مهندسی کامپیوتر دارند
# 		از جمله در سیستم‌های رمزنگاری
# 		،
# 		مبادلات اینترنتی
# 		،
# 		سیستم‌های تعیین هویت دیجیتال مانند تشخیص اثر انگشت
# 		و
# 		بررسی صحت فایل‌ها
# 		.
# 		 حل مسائلی مشابه مساله قبلی جزو کاربردهای پایه‌ای درهم‌سازی است
# 		.
#         ما ابتدا سعی می‌کنیم راه‌حل‌های موجود برای حل مسئله‌ی قبلی را با استفاده از درهم‌سازی توضیح داده و سپس به سراغ کاربرد‌های دیگر می‌رویم.
# 		<br>
# 		فرض کنید در مساله قسمت قبل تابعی داشته باشیم که اعداد بین
# 		$0$
# 		و
# 		$10^{12}$
# 		را به اعداد بین
# 		$0$
# 		تا
# 		$10^4$
# 		نگاشت کند
# 		،
# 		با این تضمین که
# 		احتمال نگاشت شدن دو عدد متفاوت به یک عدد در این بازه
# 		قابل صرف نظر باشد
# 		.
# 		حال با کمک این تابع
# 		،
# 		می توانیم ایده مساله اول را به مساله بزرگتر تعمیم دهیم
# 		،
# 		به این صورت که
# 		آرایه‌ای به طول
# 		$10^4$
# 		می گیریم و برای بررسی وجود یا عدم وجود عدد
# 		$x$
# 		به خانه
# 		$h(x)$
# 		از آرایه
# 		رجوع می کنیم
# 		.
# 		<p></p>
# 	</font>
# </div>

# %%
hash_size = 10**4 

def h(x):
    return x % hash_size

class my_set:
    table = [0] * hash_size 
    
    def insert(self, x):
        self.table[h(x)] = 1 
        
    def exists(self, x):
        return self.table[h(x)] == 1
    
    def remove(self, x):
        self.table[h(x)] = 0 
        
s = my_set() 
s.insert(10)
s.insert(245)
print(s.exists(124))
s.insert(8653)
print(s.exists(10))
s.remove(10)
print(s.exists(10))
# Out:
# False
# True
# False

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font size=6 color=#48aff1>
# 		<p></p>
# 		برخورد
# 		-
# 		Collision
# 		<p></p>
# 		</font>
# 		به وضوح نمی‌توانیم یک نگاشت یک به یک از یک مجموعه با کاردینالیتی
# 		$C_1$
# 		به
# 		مجموعه‌ای با کاردینالیتی
# 		$C_2$
# 		داشته باشیم که
# 		$C_1 > C_2$
# 		.
# 		پس
# 		حتما وقتی از تابع در‌هم ساز
# 		$h$
# 		برای نگاشت مجموعه
# 		$D$
# 		به
# 		مجموعه
# 		$L$
# 		که
# 		$|D| > |L|$
# 		استفاده می کنیم، حتما عناصر متمایزی از
# 		$D$
# 		وجود دارند که یه یک عنصر واحد در
# 		$L$
# 		نگاشت شده‌اند
# 		.
# 		<br/>
# 		به
# 		عنوان مثال
# 		،
# 		فرض کنید تابع در‌هم سازی ما در مساله قبل هر دو عدد
# 		$134$
# 		و
# 		$97$
# 		را به عدد
# 		$5$
# 		نگاشت می دهد
# 		.
# 		حال اگر بخواهیم همزمان این دو عدد
# 		را در مجموعه داشته باشیم به مشکل می خوریم
# 		.
# 		به این اتفاق برخورد یا
# 		collision
# 		می گوییم
# 		.
# 		حل کردن مشکل برخورد از مسائل پایه‌ای در طراحی توابع درهم سازی است
# 		.
# 		در عمل، ما دوست داریم از تابع درهم سازی استفاده کنیم که تعداد برخوردهای آن در سناریوهای مدنظر ما کمینه باشد
# 		.
# 		<p></p>
# 	</font>
# </div>

# %%
s.insert(10987) 
print(s.exists(987))
# Collision! 109987 % 10^4 = 987 % 10^4 = 987
# Out:
# True

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#     البته این مسئله که چنین عناصری وجود دارند،
#     به این معنی نیست که
#     حتما می‌توان به سادگی چنین اعدادی را پیدا کرد.
#     برای مثال در کاربرد‌های رمزنگاری،
#     وقتی به یک تابع درهم‌ساز خوب می‌گوییم
#     که الگوریتم کارآمدی برای پیدا کردن چنین
#     زوج اعدادی برای این تابع وجود نداشته باشد،
#     و یک تابع را فقط تا وقتی که
#     چنین زوجی برای آن پیدا نشده باشد
#     مناسب برای کار می‌دانیم.
#     </font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font size=6 color=#48aff1>
# 		<p></p>
# 		روش باقی‌مانده تقسیم
# 		<p></p>
# 		</font>
# 		از ساده ترین استراتژی‌های درهم‌سازی
# 		محاسبه باقی‌مانده تقسیم داده ورودی بر
# 		یک عدد ثابت
# 		$m$
# 		است
# 		.
# 		این دقیقا همان کاری است که در مثال قبلی انجام دادیم
# 		.
# 		<br/>
# 		$$ h(x) = x \:mod\: m $$
# 		<p></p>
# 		انتخاب مقدار
# 		مناسبه برای
# 		$m$
# 		از اهمیت بالایی برخوردار است
# 		.
# 		به عنوان مثال اگر
# 		$m$
# 		توانی از دو باشد
# 		خروجی تابع درهم‌ساز برابر
# 		$lg(m)$
# 		بیت کم ارزش
# 		$m$
# 		می شود
# 		و
# 		در نتیجه بقیه بیت‌های عدد در خروجی تابع درهم‌ساز نقشی ندارند
# 		.
# 		به طور کلی بهتر است
# 		$m$
# 		یک عدد اول و دور از توان‌های دو باشد
# 		.
# 	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font size=6 color=#48aff1>
# 		<p></p>
# 		روش ضرب
# 		<p></p>
# 		</font>
# 		یک استراتژی دیگر روش ضرب است که دو مرحله دارد. ابتدا داده‌ی ورودی
#         ضرب در یک عدد ثابت
#         $A$
#         که
#         $0 < A < 1$
#         شده و قسمت اعشاری آن گرفته می‌شود.
#         سپس این قسمت اعشاری در عدد صحیح
#         $m$
#         ضرب شده و قسمت صحیح آن گرفته می‌شود.
#         $$ h(x) = \lfloor m ( x A \:mod\: 1 ) \rfloor $$
#         که منظور از باقی‌مانده به ۱
#         همان قسمت اعشاری عدد بوده.
#         خوبی این روش این است که دیگر انتخاب عدد
#         $m$
#         اینقدر مهم نیست. معمولا در این روش
#         $m$
#         را توانی از ۲ گرفته و
#         $A$
#         را به صورت عدد گویای
#         $\frac{s}{2^w}$
#         می‌گیریم که
#         $s$
#         یک عدد صحیح در بازه‌ی
#         $0 < s < 2^w$
#         است.
# 	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font size=6 color=#48aff1>
# 		<p></p>
# 		روش همگانی - Universal hashing
# 		<p></p>
# 		</font>
# 		در تمام روش‌هایی که می‌توان برای
# 		درهم‌سازی استفاده کرد، بالاخره امکان دارد اعداد ورودی به صورتی
# 		انتخاب شوند که همه به یک خانه نگاشته شوند.
# 		یک روش برای مقابله با این مشکل این است که
# 		تعداد زیادی تابع درهم‌سازی آماده داشته باشیم
# 		و در ابتدای اجرای برنامه یکی از این توابع را
# 		به صورت مستقل از اعداد ورودی به صورت تصادفی
# 		انتخاب کرده و در ادامه‌ی برنامه از این تابع استفاده کنیم.
# 		به این کار روش همگانی درهم‌سازی گفته می‌شود.
# 		<br/>
# 		برای مثال اگر از روش ضرب استفاده می‌کنیم،
# 		می‌توانیم تعداد زیادی زوج عدد
# 		$m,A$
# 		داشته باشیم و در هنگام اجرای برنامه یکی را انتخاب کرده
# 		و باقی کار‌ها را براساس آن انجام دهیم.
# 		<br/>
# 		ثابت می‌شود که این روش به طور متوسط حتی روی بدترین ورودی ممکن
# 		روش کارآمدی است.
# 	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font size=6 color=#48aff1>
# 		<p></p>
# 		روش‌های مقابله با برخورد‌ها
# 		<p></p>
# 		</font>
#         <hr/>
#         تا به حال سعی می‌کردیم تا توابعی پیدا کنیم
# 		که احتمال برخورد را کم کنیم.
# 		اما در هر صورت
# 		اگر بخواهیم
# 		تعداد زیادی عدد را در یک جدول با اندازه‌ی کوچک
# 		ذخیره کنیم، حتما برخورد خواهیم داشت.
# 		برای حل این مشکل دو روش کلی وجود دارد:
# 		<ul>
# 			<li>زنجیره‌سازی</li>
# 			<li>آدرس‌دهی آزاد</li>
# 		</ul>
# 	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font size=6 color=#48aff1>
# 		<p></p>
# 		زنجیره‌سازی
# 		<p></p>
# 		</font>
#         در این روش، هر خانه‌ی جدول را
#         یک لیست پیوندی‌ می‌گیریم.
#         حال هر عدد را که می‌خواهیم به خانه‌ای
#         اضافه کنیم، خود عدد را در انتهای لیست آن خانه
#         اضافه می‌کنیم. برای چک کردن وجود هم
#         باید کل لیست آن خانه را بگردیم
#         تا این که یا لیست تمام شود یا
#         عدد مورد نظر را پیدا کنیم.
#         <br/>
#         این روش شاید به نظر کارا نیاید
#         اما دقت کنید که فرض کرده بودیم
#         قرار نیست تعداد زیادی برخورد داشته باشیم.
# 	</font>
# </div>

# %%
class my_chained_set:
    table = [[] for _ in range(hash_size)]

    def insert(self, x):
        if not self.exists(x):
            self.table[h(x)].append(x) # O(1)

    def exists(self, x):
        return x in self.table[h(x)]   # O(size of list)

    def remove(self, x):
        self.table[h(x)].remove(x)     # O(size of list)

s = my_chained_set()
s.insert(10)
s.insert(245)
print(s.exists(10))

s.insert(10987)
print(s.exists(987))  # right answer!
# Out:
# True
# False

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font size=6 color=#48aff1>
# 		<p></p>
# 		آدرس‌دهی باز
# 		<p></p>
# 		</font>
#         در این روش، برعکس روش قبل اعداد را در همان
# 		خانه‌های جدول نگه‌داری می‌کنیم،
# 		با این تفاوت که اگر به خانه‌ی اصلی رفتیم و پر بود،
# 		به سراغ خانه‌ی (مشخص) دیگری می‌رویم.
# 		مثلا فرض کنید که همیشه درست دنبال خانه‌ی بعدی برویم
# 		و اگر آنجا خالی بود، عددمان را در آنجا قرار دهیم،
# 		اگر نه باز هم ادامه دهیم تا به یک خانه‌ی خالی برسیم.
# 		<br/>
# 		اگر فرض کنیم که اندازه‌ی جدول خیلی بزرگ‌تر از تعداد عناصر داخل آن باشد،
# 		به امکان زیاد خیلی نیاز نمی‌شود که
# 		دنبال خانه‌ی دیگری برویم.
# 		حال برای پیدا کردن یک عضو چی می‌کنیم؟
# 		باید ابتدا سراغ خانه‌ی اصلی برویم و اگر خالی بود که
# 		عدد در جدول نیست و اگر هم خود عدد در داخلش
# 		قرار داشت که عدد پیدا شده و وجود دارد.
# 		اگر خالی نبود ولی عدد ما هم در آن نبود،
# 		باید به سراغ خانه‌ی بعدی برویم
# 		تا وقتی که به یک خانه‌ی خالی برسیم.
# 		برای حذف کردن هم ابتدا باید عنصر پیدا شود، سپس تا آخر دنباله‌ی
# 		خانه‌های خالی رفته و آخرین عدد از این مجموعه (اگر وجود داشت)
# 		به جای خودش قرار دهیم.
# 		<br/>
# 		البته در این روش
# 		اگر خود خانه خالی بود، حتما به سراغ خانه‌ی
# 		بعدی نمی‌رویم،
# 		بلکه تابع درهم‌ساز ما باید دو ورودی بگیرد
# 		$h(x,i)$
# 		و ابتدا ما به خانه‌ی
# 		$h(x,0)$
# 		می‌رویم. اگر پر بود به سراغ
# 		$h(x,1)$
# 		و
# 		$h(x,2)$
# 		و
# 		...
# 		می‌رویم تا یک خانه‌ی خالی پیدا کنیم.
# 		<br/>
# 		برای ساختن این تابع معمولا یکی از سه روش زیر را استفاده می‌کنیم:
#
# 		<font size=5 color=#48aff1>
# 		<p></p>
# 		۱- کاوش خطی
# 		<p></p>
# 		</font>
# 		این روش تقریبا همان روش رفتن به خانه‌ی بعدی است. به این صورت که
# 		اگر اعضای جدول اعداد صفر تا
# 		$m$
# 		باشند، تابع درهم‌ساز جدید را بر اساس تابع درهم‌ساز قبلی به صورت زیر می‌سازیم:
# 		$$h(x,i) = (h'(x) + i) \:mod\: m$$
# 		اما در این روش معمولا مشکلی به نام
# 		دسته‌بندی اولیه (Primary Clustering)
# 		پیش می‌آید که یعنی دنباله‌های پشت‌سر هم طولانی ساخته شده
# 		و در نتیجه زمان جستجو افزایش می‌یابد.
# 		<font size=5 color=#48aff1>
# 		<p></p>
# 		۲- کاوش مربعی
# 		<p></p>
# 		</font>
# 		در این روش فرم تابع مورد استفاده به صورت زیر خواهد بود
# 		$$h(x,i) = (h'(x) + c_1i + c_2i^2) \:mod\: m$$
# 		اما باز هم اگر دو دسته تابع درهم‌ساز اولیه‌شان یکی باشد
# 		باز هم دنباله‌‌شان یکسان خواهد بود.
# 		به این مشکل نیز
# 		دسته‌بندی ثانوی (Secondary Clustering)
# 		می‌گویند.
#
# 		<font size=5 color=#48aff1>
# 		<p></p>
# 		۳- درهم‌سازی دوتایی
# 		<p></p>
# 		</font>
# 		در این روش
# 		برای حل مشکلات دو روش قبلی
# 		از دو تابع درهم‌ساز متفاوت به صورت زیر استفاده می‌شود:
# 		$$h(x,i) = (h_1(x) + ih_2(x)) \:mod\: m$$
# 	</font>
# </div>
